# %% [markdown]
# <a href="https://colab.research.google.com/github/satyam-singh9828/3rd-year-projects-/blob/main/read_image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2
from google.colab.patches import cv2_imshow # exclusively for google colab
#cv2.imshow() is disable in colab, because it causes jupyter session to crash

# %%
a = cv2.imread('/content/drive/My Drive/images/1139.jpg')

a.shape
# Out:
# (531, 413, 3)

# %%
px = a[100,20]
print(px) # BGR
# Out:
# [162 167 166]

# %%
#a[100,20] = [0,0,255]
for x in range(100,150):
  a[x,20] = [255,0,0]

# %%
cv2_imshow(a)
# Out:
# <PIL.Image.Image image mode=RGB size=413x531>

# %% [markdown]
# **Binary Image**

# %%
randbin = np.random.choice([0,255],size = (100000,),p = [1./3,2./3])
flatnpArray = np.array(randbin,dtype = np.uint8)
binimg = flatnpArray.reshape(200,500)
cv2_imshow(binimg)
# Out:
# <PIL.Image.Image image mode=L size=500x200>

# %% [markdown]
# **Grayscale image**

# %%
bg = cv2.cvtColor(a,cv2.COLOR_BGR2GRAY)
cv2_imshow(bg)
# Out:
# <PIL.Image.Image image mode=L size=413x531>
